# %% [markdown]
# # 📚 AI Research Paper Intelligence System
#
# ## Notebook 1: Data Preparation
#
# ### Objectives
# - Load the ML-ArXiv research paper dataset
# - Explore the dataset
# - Clean the dataset
# - Save the cleaned dataset for later notebooks

# %%
import os
import sys
import importlib

project_root = os.path.abspath("..")

if project_root not in sys.path:
    sys.path.insert(0, project_root)

import utils.preprocessing
importlib.reload(utils.preprocessing)

from utils.preprocessing import preprocess, text_statistics

# %%
# ==========================================
# Import Required Libraries
# ==========================================

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

# Display settings
pd.set_option("display.max_columns", None)
pd.set_option("display.max_colwidth", 200)

print("Libraries imported successfully!")
# Out:
# Libraries imported successfully!

# %%
from datasets import load_dataset

dataset = load_dataset("CShorten/ML-ArXiv-Papers")

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['Unnamed: 0.1', 'Unnamed: 0', 'title', 'abstract'],
#         num_rows: 117592
#     })
# })

# %%
# Convert Hugging Face dataset to Pandas DataFrame
papers = dataset["train"].to_pandas()

print("Dataset converted successfully!")
# Out:
# Dataset converted successfully!

# %%
papers.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  \
# 0             0         0.0
# 1             1         1.0
# 2             2         2.0
# 3             3         3.0
# 4             4         4.0
#
#                                                                              title  \
# 0                                            Learning from compressed observations
# 1  Sensor Networks with Random Links: Topology Design for Distributed\n  Consensus
# 2                       The on-line shortest path problem under partial monitoring
# 3                                  A neural network approach to ordinal regression
# 4                                 Parametric Learning and Monte Carlo Optimization
#
#                                                                                                                                                                                                   abstract
# ...

# %%
print(f"Number of Rows    : {papers.shape[0]}")
print(f"Number of Columns : {papers.shape[1]}")
# Out:
# Number of Rows    : 117592
# Number of Columns : 4

# %%
papers.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 117592 entries, 0 to 117591
# Data columns (total 4 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Unnamed: 0.1  117592 non-null  int64
#  1   Unnamed: 0    112592 non-null  float64
#  2   title         117592 non-null  str
#  3   abstract      117592 non-null  str
# dtypes: float64(1), int64(1), str(2)
# memory usage: 141.6 MB

# %%
papers.isnull().sum()
# Out:
# Unnamed: 0.1       0
# Unnamed: 0      5000
# title              0
# abstract           0
# dtype: int64

# %%
papers = papers.drop(columns=["Unnamed: 0.1", "Unnamed: 0"])

papers.head()
# Out:
#                                                                              title  \
# 0                                            Learning from compressed observations
# 1  Sensor Networks with Random Links: Topology Design for Distributed\n  Consensus
# 2                       The on-line shortest path problem under partial monitoring
# 3                                  A neural network approach to ordinal regression
# 4                                 Parametric Learning and Monte Carlo Optimization
#
#                                                                                                                                                                                                   abstract
# 0    The problem of statistical learning is to construct a predictor of a random\nvariable $Y$ as a function of a related random variable $X$ on the basis of an\ni.i.d. training sample from the joint...
# ...

# %%
papers = papers.dropna()

print("Remaining papers:", len(papers))
# Out:
# Remaining papers: 117592

# %%
papers = papers.drop_duplicates()

print("Unique papers:", len(papers))
# Out:
# Unique papers: 117569

# %%
papers.sample(5)
# Out:
#                                                                                         title  \
# 40623   A Quotient Space Formulation for Generative Statistical Analysis of\n  Graphical Data
# 15313                                Stochastic Nonconvex Optimization with Large Minibatches
# 112636                                                           Symbolic-Regression Boosting
# 63055                                                    One Weight Bitwidth to Rule Them All
# 83008                                                              Gradient Assisted Learning
#
#                                                                                                                                                                                                        abstract
# ...

# %%
papers.to_csv("../data/cleaned_papers.csv", index=False)

print("✅ Cleaned dataset saved successfully!")
# Out:
# ✅ Cleaned dataset saved successfully!

# %%
import os

print(os.listdir(".."))
# Out:
# ['data', 'dataset.md', 'models', 'notebooks', 'requirement.txt', 'uploads', 'utils', 'vector_db', 'venv']
